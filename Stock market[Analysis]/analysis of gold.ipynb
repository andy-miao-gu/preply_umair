# %%
import yfinance as yf
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
gold = yf.Ticker("GC=F")

start_date = "2020-01-01"
end_date = "2023-01-01"

# %%
gold_data =  gold.history(period="id",start=start_date,end = end_date   )

# %%
gold_data
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2020-01-02 00:00:00-05:00  1518.099976  1528.699951  1518.000000  1524.500000
# 2020-01-03 00:00:00-05:00  1530.099976  1552.699951  1530.099976  1549.199951
# 2020-01-06 00:00:00-05:00  1580.000000  1580.000000  1560.400024  1566.199951
# 2020-01-07 00:00:00-05:00  1558.300049  1576.300049  1558.300049  1571.800049
# 2020-01-08 00:00:00-05:00  1579.699951  1604.199951  1552.300049  1557.400024
# ...                                ...          ...          ...          ...
# 2022-12-23 00:00:00-05:00  1794.300049  1802.800049  1794.099976  1795.900024
# 2022-12-27 00:00:00-05:00  1803.400024  1826.300049  1803.400024  1814.800049
# 2022-12-28 00:00:00-05:00  1803.199951  1807.900024  1803.099976  1807.900024
# 2022-12-29 00:00:00-05:00  1805.800049  1819.500000  1805.800049  1819.500000
# 2022-12-30 00:00:00-05:00  1817.000000  1822.300049  1816.800049  1819.699951
#
# ...

# %%
plt.figure(dpi=675)
sns.lineplot(gold_data[['Open','High']])
# Out:
# <Axes: xlabel='Date'>

# %%
gold_data = gold_data.reset_index()

# %%
gold_data.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends',
#        'Stock Splits'],
#       dtype='object')

# %%
gold_data.sort_values('Open',ascending=False)
# Out:
#                          Date         Open         High          Low  \
# 550 2022-03-09 00:00:00-05:00  2053.600098  2063.000000  1980.800049
# 150 2020-08-06 00:00:00-04:00  2045.500000  2063.000000  2040.000000
# 151 2020-08-07 00:00:00-04:00  2040.099976  2055.000000  2009.599976
# 152 2020-08-10 00:00:00-04:00  2026.400024  2043.800049  2017.500000
# 149 2020-08-05 00:00:00-04:00  2024.000000  2050.199951  2011.000000
# ..                        ...          ...          ...          ...
# 0   2020-01-02 00:00:00-05:00  1518.099976  1528.699951  1518.000000
# 55  2020-03-23 00:00:00-04:00  1505.300049  1567.000000  1490.199951
# 54  2020-03-20 00:00:00-04:00  1483.500000  1484.000000  1483.500000
# 53  2020-03-19 00:00:00-04:00  1481.500000  1491.599976  1471.000000
# 51  2020-03-17 00:00:00-04:00  1469.300049  1537.699951  1469.300049
#
#            Close  Volume  Dividends  Stock Splits
# 550  1985.900024    1022        0.0           0.0
# ...

# %%
plt.figure(figsize=(16,8),dpi=675)
import plotly.express as px

# Assuming 'Date' and 'Volume' are columns in your DataFrame
fig = px.scatter(gold_data, x='Date', y='Volume', title='Scatter Plot of Gold Data')
fig.show()
