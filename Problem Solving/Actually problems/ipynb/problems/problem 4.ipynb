# %%
theBoard = {'top-L': ' ', 'top-M': ' ', 'top-R': ' ', 'mid-L': ' ', 'mid-M': ' ', 'mid-R': ' ', 'low-L': ' ', 'low-M': ' ', 'low-R': ' '}
def printBoard(board):
       print(board['top-L'] + '|' + board['top-M'] + '|' + board['top-R'])
       print('-+-+-')
       print(board['mid-L'] + '|' + board['mid-M'] + '|' + board['mid-R'])
       print('-+-+-')
       print(board['low-L'] + '|' + board['low-M'] + '|' + board['low-R'])
turn = 'X'
for i in range(9):
    printBoard(theBoard)
    print('Turn for ' + turn + '. Move on which space?')
    move = input()
    theBoard[move] = turn
    if turn == 'X':
           turn = 'O'
    else:
        turn = 'X'
printBoard(theBoard)
# Out:
#  | |
# -+-+-
#  | |
# -+-+-
#  | |
# Turn for X. Move on which space?
#  | |
# -+-+-
#  | |
# -+-+-
#  | |
# Turn for O. Move on which space?
#  | |
# -+-+-
#  | |
# -+-+-
#  | |
# Turn for X. Move on which space?
#  | |
# -+-+-
#  | |
# -+-+-
#  | |
# Turn for O. Move on which space?
#  | |
# -+-+-
#  | |
# -+-+-
#  | |
# Turn for X. Move on which space?
#  | |
# -+-+-
#  | |
# -+-+-
#  | |
# Turn for O. Move on which space?
#  | |
# -+-+-
#  | |
# -+-+-
#  | |
# Turn for X. Move on which space?
#  | |
# -+-+-
#  | |
# -+-+-
#  | |
# Turn for O. Move on which space?
#  | |
# -+-+-
#  | |
# -+-+-
#  | |
# Turn for X. Move on which space?
#  | |
# -+-+-
#  | |
# -+-+-
#  | |

# %%
heBoard = {'top-L': 'O', 'top-M': 'O', 'top-R': 'O',
            'mid-L': 'X', 'mid-M': 'X', 'mid-R': ' ',
            'low-L': ' ', 'low-M': ' ', 'low-R': 'X'}
def printBoard(board):
    print(board['top-L'] + '|' + board['top-M'] + '|' + board['top-R'])
    print('-+-+-')
    print(board['mid-L'] + '|' + board['mid-M'] + '|' + board['mid-R'])
    print('-+-+-')
    print(board['low-L'] + '|' + board['low-M'] + '|' + board['low-R'])
printBoard(theBoard)
# Out:
#  | |
# -+-+-
#  | |
# -+-+-
#  | |

# %% [markdown]
# 1. What does the code for an empty dictionary look like?
# 2. What does a dictionary value with a key 'foo' and a value 42 look like?
# 3. What is the main difference between a dictionary and a list?
# 4. What happens if you try to access spam['foo'] if spam is {'bar': 100}?
# 5. If a dictionary is stored in spam, what is the difference between the expressions 'cat' in spam and 'cat' in spam.keys()?
# 6. If a dictionary is stored in spam, what is the difference between the expressions 'cat' in spam and 'cat' in spam.values()?
# 7. What is a shortcut for the following code?

# %%
### make a code in whic you have to load mango.txt file
## you have to collect all fruitop names
sssliver=open("mango.txt")
emarfatad=sssliver.read()

# %%
## emarfatad please replace \\n with " "
emarfatad = emarfatad.replace("\\n"," ")

# %%
lst_of_str = emarfatad.split("\n")
lst_of_str
# Out:
# ['Fruit Name\\tPrice\\tColor\\tShape ',
#  'Apple\\t0.99\\tRed\\tRound ',
#  'Banana\\t0.49\\tYellow\\tCurved ',
#  'Orange\\t0.75\\tOrange\\tRound ',
#  'Grapes\\t1.25\\tPurple\\tOval ',
#  'Watermelon\\t3.50\\tGreen & Pink\\tOval ',
#  'Pineapple\\t1.99\\tYellow & Brown\\tOval ',
#  'Strawberry\\t0.35\\tRed\\tHeart-shaped ',
#  'Mango\\t1.75\\tYellow\\tOval ',
#  'Kiwi\\t0.95\\tGreen\\tOval ',
#  'Pear\\t0.89\\tGreen & Brown\\tOblong ',
#  'Blueberry\\t0.60\\tBlue\\tSpherical ',
#  'Cherry\\t1.15\\tRed\\tSpherical ',
#  'Peach\\t1.25\\tOrange\\tOval ',
#  'Lemon\\t0.70\\tYellow\\tOval ',
#  'Plum\\t0.80\\tPurple & Red\\tOval ',
#  'Raspberry\\t1.50\\tRed or Black\\tSpherical ',
#  'Blackberry\\t1.20\\tBlack\\tSpherical ',
#  'Pomegranate\\t1.80\\tRed & Pink\\tRound ',
#  'Cantaloupe\\t2.25\\tOrange & Green\\tOval ',
#  'Dragonfruit\\t2.99\\tPink & Green\\tOval ']

# %%
for eap in lst_of_str:
    print(eap.split('\\t')[0])
# Out:
# Fruit Name
# Apple
# Banana
# Orange
# Grapes
# Watermelon
# Pineapple
# Strawberry
# Mango
# Kiwi
# Pear
# Blueberry
# Cherry
# Peach
# Lemon
# Plum
# Raspberry
# Blackberry
# Pomegranate
# Cantaloupe
# Dragonfruit

# %%
## i will send you a text file and you have to collect the longest word
news = open("news.txt")
news=news.read()
news=news.replace("\n"," ")

# %%
new=news.split(" ")
new
# Out:
# ["Japan's",
#  'government',
#  'has',
#  'finalized',
#  'when',
#  'it',
#  'will',
#  'begin',
#  'releasing',
#  'treated',
#  'and',
#  'diluted',
#  'water',
#  'from',
#  'the',
#  'Fukushima',
#  'Daiichi',
#  'nuclear',
#  'power',
#  'plant',
#  'into',
#  'the',
#  'ocean.',
#  'The',
#  'plan',
#  'sets',
#  'into',
#  'motion',
#  'as',
#  'soon',
#  'as',
#  'Thursday.',
#  '',
#  'Prime',
#  'Minister',
#  'Kishida',
#  'Fumio',
#  'made',
#  'the',
#  'announcement',
#  'while',
#  'meeting',
#  'with',
#  'Cabinet',
#  'members',
#  'on',
#  'Tuesday.',
#  '',
#  'He',
#  'said,',
#  '"The',
#  'release',
#  'is',
#  'expected',
#  'on',
#  'Thursday,',
#  'as',
#  'long',
#  'as',
#  'weather',
#  'and',
#  'sea',
#  'conditions',
#  "don't",
#  'cause',
#  'any',
#  'issues.',
#  'We',
#  'will',
#  'take',
#  'responsibility',
#  'until',
#  'the',
#  'discharge',
#  'of',
#  'the',
#  'treated',
#  'water',
#  'is',
#  'completed,',
#  'no',
#  'matter',
# ...

# %%
for each in new:
    if len(each)>13:
        print(each)
###print("supercalifrajalisticexpicalidoucious")
# Out:
# responsibility
# Organization's

# %%
## tell me those words which are starting from a
for ea in new:
    if ea:
        if ea[0].lower() == "f" and ea[-1].lower() == "s":
            print(ea)

# %%
## go to America news 


# select news



## and Select those words whihc are startign with a and b
