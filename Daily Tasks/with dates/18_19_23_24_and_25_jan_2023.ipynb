# %%
    A ="A"
B ="B"
C ="C"
D ="D"
E ="E"
F ="F"
G ="G"
H ="H"
I ="I"
J ="J"
K ="K"
L ="L"
M ="M"
N ="N"
O ="O"
P ="P"
Q ="Q"
R ="R"
S ="S"
T ="T"
U ="U"
V ="V"
W ="W"
X ="X"
Y ="Y"
Z ="Z"

# %%
a ="a"
b ="b"
c ="c"
d ="d"
e ="e"
f ="f"
g ="g"
h ="h"
i ="i"
j ="j"
k ="k"
l ="l"
m ="m"
n ="n"
o ="o"
p ="p"
q ="q"
r ="r"
s ="s"
t ="t"
u ="u"
v ="v"
w ="w"
x ="x"
y ="y"
z ="z"

# %%
per = "."
com = ","
exc = "!"
que = "?"

# %%
print(r,e,exc,f,com,d)
# Out:
# r e ! f , d

# %%
y = print(input("who are you"))
print(y,y,y,y,y,y,y,y,y,y,y,y,y,y)
# Out:
# who are yout
# t
# None None None None None None None None None None None None None None

# %%
sandwich_orders = list(("tuna","chicken","burger"))
if not "pastrami" in eval("sandwich_orders"):
    sandwich_orders.append("pastrami")
finish_sandwichs = list(())
for each in sandwich_orders:
    print(I,m+a+d+e,eval(e+a+c+h),s+a+n+d+w+i+c+h)
# Out:
# I made tuna sandwich
# I made chicken sandwich
# I made burger sandwich
# I made pastrami sandwich

# %%
#### use while loop and keep on appending sanwitch but not add patromis

# %%
sandwich_orders = list(("tuna","chicken","burger"))
if not "pastrami" in eval("sandwich_orders"):
    sandwich_orders.append("pastrami")
finish_sandwichs = list(())
for each in sandwich_orders:
    print(I,m+a+d+e,eval(e+a+c+h),s+a+n+d+w+i+c+h)
print(S+o+r+r+y,t+h+e+r+e,i+s,n+o,m+o+r+e,eval(p+a+s+t+r+a+m+i))
sandwich_orders.remove("pastrami")
print(I,d+i+d,n+o+t,m+a+k+e,eval(e+a+c+h),s+a+n+d+w+i+c+h)
# Out:
# I made tuna sandwich
# I made chicken sandwich
# I made burger sandwich
# I made pastrami sandwich
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/0k/rfc7l8w10vg2gy6fqthn9r9r0000gn/T/ipykernel_13972/266329503.py in <module>
#       5 for each in sandwich_orders:
#       6     print(I,m+a+d+e,eval(e+a+c+h),s+a+n+d+w+i+c+h)
# ----> 7 print(S+o+r+r+y,t+h+e+r+e,i+s,n+o,m+o+r+e,eval(p+a+s+t+r+a+m+i))
#       8 sandwich_orders.remove("pastrami")
#       9 print(I,d+i+d,n+o+t,m+a+k+e,eval(e+a+c+h),s+a+n+d+w+i+c+h)
#
# <string> in <module>
#
# NameError: name 'pastrami' is not defined

# %%
sandwich_orders = list(("tuna","pastrami","chicken","pastrami","burger","pastrami"))
finished = sandwich_orders.copy()
print("deli has ran out of pastrami")
while("pastrami" in finished):
    finished.remove("pastrami")
print(sandwich_orders)

print(finished)
# Out:
# deli has ran out of pastrami
# ['tuna', 'pastrami', 'chicken', 'pastrami', 'burger', 'pastrami']
# ['tuna', 'chicken', 'burger']

# %%
t = print
t(w+e+e+e+e+e+e+e+e+e+e+e+e+e+e+e+e+e+e+e+e+e+e+e+e+e+e+e+e+e+e+e+e+e+e+e+e)
# Out:
# weeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee

# %%
w### +makee ;empty list
## us

# %%
_ = []
while True:
    place  =    input(   " fav place? "    )  
    if place ==  "quit" :
        break
    _.append(place)
print(set(_))

# %%
help(str)qq
q

# %%
def display_message():
    """Display a message about what I'm learning."""
    msg = "I'm learning to store code in functions."
    print(msg)

display_message()
# Out:
# I'm learning to store code in functions.

# %%
def fav_book():
    """Display a message about what I'm learning."""
    dgr = "My fav book series is the happy life series"
    
    print(eval(d+g+r))
    
fav_book()
# Out:
# My fav book series is the happy life series

# %%
def make_shirt():
    """make a T-shirt size"""
    hyuy = input("say the T-shirt's size ")
    while(hyuy not in [s,m,l,100,110,120,130,140,150,160,170,180,190,200,210,276]):
        
        print("the size of the T-shirt is",hyuy)
        if hyuy == "s" or hyuy =="small":
            print("the T-shirt is small size")
        elif hyuy == "m" or hyuy == "medium":
            print("the T-shirt is medium size")
        elif hyuy == "l" or hyuy == "large":
            print("the T-shirt is large size")
            break
        print("the size of the T-shirt is",hyuy)
        hyuy = input("say the T-shirt's size ")
make_shirt()

# %%
pri = print
pri("t")

# %%
word = "smallx"
if "x" in word:
    print("yeyyy")

# %%
one = "1"
two = "2"
tre = "3"
fou = "4"
fiv = "5"
six = "6"
sev = "7"
eig = "8"
nin = "9"
ten = "10"

# %%
inp = input("describe iceland ")
def describe_city(inp):
    """describe iceland"""
    print("you said that iceland is",inp)
describe_city(inp)
# Out:
# describe iceland icy
# you said that iceland is icy

# %%
while True:
    import turtle
    bg = "red"
    color = "red"
    turtle.forward(350)        
    turtle.right(145)
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/turtle.py in forward(distance)
#
# ~/opt/anaconda3/lib/python3.9/turtle.py in forward(self, distance)
#    1637         """
# -> 1638         self._go(distance)
#    1639
#
# ~/opt/anaconda3/lib/python3.9/turtle.py in _go(self, distance)
#    1605         ende = self._position + self._orient * distance
# -> 1606         self._goto(ende)
#    1607
#
# ~/opt/anaconda3/lib/python3.9/turtle.py in _goto(self, end)
#    3177                 if self._drawing:
# -> 3178                     screen._drawline(self.drawingLineItem,
#    3179                                      (start, self._position),
#
# ~/opt/anaconda3/lib/python3.9/turtle.py in _drawline(self, lineitem, coordlist, fill, width, top)
#     543                 cl.append(-y * self.yscale)
# --> 544             self.cv.coords(lineitem, *cl)
# ...

# %%
def city_country(city,country):
    """the city and what contry that city is"""
    return f"""{city.title()}{com} {country.title()}"""

print(city_country("tokyo", "japan"))
city_country("gujrat", "pakistan")
# Out:
# Tokyo, Japan
# 'Gujrat, Pakistan'

# %%
spa = " "

# %%
def make_album(name, title,num=None):
    return {name:title,"number of tracks":num}
d1=make_album("I dont know1", "I dont know song1",54)
d2=make_album("I dont know2", "I dont know song2",42)
d3=make_album("I dont know5","I dont know song5",100)
d4=make_album("I dont know3", "I dont know song3",142)
print(d1,d2,d3,d4)
# Out:
# {'I dont know1': 'I dont know song1', 'number of tracks': 54} {'I dont know2': 'I dont know song2', 'number of tracks': 42} {'I dont know5': 'I dont know song5', 'number of tracks': 100} {'I dont know3': 'I dont know song3', 'number of tracks': 142}

# %% [markdown]
# #write a while loop
# ### call function with name and title PREPLEY

# %%
def make_album(name,album):
    """the album"""
    return {name:album}
    
dall={}
while(True):
    sd = input("what is your name ")
    ss = input("what is the album ")
    if sd=="quit" or ss == "quit":
        break
    dall[sd] = make_album(sd,ss)
    dall[sd]=ss
    
for sd,ss in dall.items():
    print("your username is going to be",sd+".hello@idon'tknow.mk")
    print("your passcode is going to be",ss+","+sd+".@idonv'tknow.mjdk")
# Out:
# what is your name bca
# what is the album yyeeeyyye
# what is your name and
# what is the album sjlkdjsldjsajld
# what is your name qtiu
# what is the album quit
# your username is going to be bca.hello@idon'tknow.mk
# your passcode is going to be yyeeeyyye,bca.@idonv'tknow.mjdk
# your username is going to be and.hello@idon'tknow.mk
# your passcode is going to be sjlkdjsldjsajld,and.@idonv'tknow.mjdk

# %%
print("🍎😋")
# Out:
# 🍎😋

# %% [markdown]
# # ![image of shanghai](https://theplanetd.com/images/things-to-do-in-shanghai-1.jpg)

# %% [markdown]
# # ![image of italy](https://www.state.gov/wp-content/uploads/2018/11/Italy-2109x1406.jpg)

# %%
 # ![image of italy](https://www.state.gov/wp-content/uploads/2018/11/Italy-2109x1406.jpg)
# ![image of italy](https://theplanetd.com/images/things-to-do-in-shanghai-1.jpg)

# %%
def show_magicians(x):
    """magicicians"""
    for i in x :
        print( i)
rrrr = list(("umair","mair","air","ir","r"))
show_magicians(rrrr)
# Out:
# umair
# mair
# air
# ir
# r

# %%
def x (y):
    for i in range(len(y)+1):
        print(y[-i:])
    for i in range(len(y)+1):
        print(y[i:])
        
x("abcdefghijklmnopqrstuvwxyz")
# Out:
# abcdefghijklmnopqrstuvwxyz
# z
# yz
# xyz
# wxyz
# vwxyz
# uvwxyz
# tuvwxyz
# stuvwxyz
# rstuvwxyz
# qrstuvwxyz
# pqrstuvwxyz
# opqrstuvwxyz
# nopqrstuvwxyz
# mnopqrstuvwxyz
# lmnopqrstuvwxyz
# klmnopqrstuvwxyz
# jklmnopqrstuvwxyz
# ijklmnopqrstuvwxyz
# hijklmnopqrstuvwxyz
# ghijklmnopqrstuvwxyz
# fghijklmnopqrstuvwxyz
# efghijklmnopqrstuvwxyz
# defghijklmnopqrstuvwxyz
# cdefghijklmnopqrstuvwxyz
# bcdefghijklmnopqrstuvwxyz
# abcdefghijklmnopqrstuvwxyz
# abcdefghijklmnopqrstuvwxyz
# bcdefghijklmnopqrstuvwxyz
# cdefghijklmnopqrstuvwxyz
# defghijklmnopqrstuvwxyz
# efghijklmnopqrstuvwxyz
# fghijklmnopqrstuvwxyz
# ghijklmnopqrstuvwxyz
# hijklmnopqrstuvwxyz
# ijklmnopqrstuvwxyz
# jklmnopqrstuvwxyz
# klmnopqrstuvwxyz
# lmnopqrstuvwxyz
# mnopqrstuvwxyz
# nopqrstuvwxyz
# opqrstuvwxyz
# pqrstuvwxyz
# qrstuvwxyz
# rstuvwxyz
# stuvwxyz
# tuvwxyz
# uvwxyz
# vwxyz
# wxyz
# xyz
# yz
# z

# %%
y = "hjkl"
print(y[2:])
# Out:
# kl

# %% [markdown]
# # a function that send greetings to each member of list if you call that functions

# %%
def xyz(a):
    for each in a:
        if each !="o":
            print(each)

xyz("hellooooooo")
# Out:
# h
# e
# l
# l

# %%
def my_fun(y):
    print("hello",y)
    my_fun("äńdÿ")
my_fun(y)
# Out:
# hello y
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# hello äńdÿ
# ...

# %%
print(one)
# Out:
# 1

# %%
def andy(*parameter):
    for each in parameter:
        if "e" in each:
            print("arguments with e",each)
        else:
            print("arguments with not e",each)
    

andy("apple","green","vampire,","Umair")
andy("lemon","tea","pomogranete","sara")
andy("andy","onion","banana","lime")
andy("edward mango","zebra","purple","Air")
andy("mango","orange","lion","snap pea")
# Out:
# arguments with e apple
# arguments with e green
# arguments with e vampire,
# arguments with not e Umair
# arguments with e lemon
# arguments with e tea
# arguments with e pomogranete
# arguments with not e sara
# arguments with not e andy
# arguments with not e onion
# arguments with not e banana
# arguments with e lime
# arguments with e edward mango
# arguments with e zebra
# arguments with e purple
# arguments with not e Air
# arguments with not e mango
# arguments with e orange
# arguments with not e lion
# arguments with e snap pea

# %%
print(tuple(("apple","orange")))
# Out:
# ('apple', 'orange')

# %%
def fun(x):
    for each in x:
        print(each)
        
fun(("cat","dog","donkey","aeroplane"))
# Out:
# cat
# dog
# donkey
# aeroplane

# %%
def make_sandwich():
    """make sandwich orders"""
    ed = input('whart topping is your sandwich gonna be')
    de = input('whart topping is your sandwich gonna be')
    edd = input('whart topping is your sandwich gonna be')
    dee = input('whart topping is your sandwich gonna be')
    print("i will make you a"+com,ed+com,de+com,edd,"and",dee,"sandwich")
make_sandwich()
# Out:
# whart topping is your sandwich gonna ber
# whart topping is your sandwich gonna ber
# whart topping is your sandwich gonna ber
# whart topping is your sandwich gonna ber
# i will make you a, r, r, r and r sandwich

# %%
def make_sandwiches(*parameter):
    for each in parameter:
        print(each)
        
make_sandwiches("boba","tapiyoca","Mr. Umair","sara","andy not angela","angela not andy")
# Out:
# boba
# tapiyoca
# Mr. Umair
# sara
# andy not angela
# angela not andy

# %%
def user_profile(first, last, **user_info):
    """Build a dictionary containing everything we know about a user."""
    profile = {}
    profile['first_name'] = first
    profile['last_name'] = last
    for key, value in user_info.items():
        profile[key] = value
    return profile
user_profile = user_profile('andy', 'gu',
                             location='hikarigaoka',
                             field='math',
                             hobby="coding",
                             profession="mathematician",
                             age = 8
                            )
print(user_profile)
# Out:
# {'first_name': 'andy', 'last_name': 'gu', 'location': 'hikarigaoka', 'field': 'math', 'hobby': 'coding', 'profession': 'mathematician', 'age': 8}

# %%
s = "andy not angela"
print(s.replace("andy","angela"))
# Out:
# angela not angela

# %%
def make_car(first, last, **user_info):
    """Build a dictionary containing everything we know about a user."""
    profile = {}
    profile['manufacture'] = first
    profile['model_name'] = last
    
    for key, value in user_info.items():
        profile[key] = value
    return profile
user_profile = make_car('tesla', "lambargini",
                             outback='saburu',
                             color='blue',
                             tow_package=True)
                             
                            
print(user_profile)
# Out:
# {'manufacture': 'samsung', 'model_name': 'honda', 'outback': 'saburu', 'color': 'blue', 'tow_package': True}
