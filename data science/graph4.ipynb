# %%
import pandas as pd
data = pd.read_csv('StudentsPerformance.csv')

# %%
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
import seaborn as saor
import matplotlib.pyplot as mtltippo
mtltippo.figure(figsize=(10, 4))
saor.violinplot(data=data, x="parental level of education", y="math score",split=True,hue ='gender')
# Out:
# <AxesSubplot:xlabel='parental level of education', ylabel='math score'>

# %%
mtltippo.figure(figsize=(10, 4))
saor.violinplot(data=data, x="parental level of education", y="math score",inner="q",split=True, bw_adjust=0.2 )
# Out:
# <AxesSubplot:xlabel='parental level of education', ylabel='math score'>

# %%
mtltippo.figure(figsize=(10, 4))
saor.violinplot(data=data, x="parental level of education", y="math score",inner='stick')
# Out:
# <AxesSubplot:xlabel='parental level of education', ylabel='math score'>

# %%
mtltippo.figure(figsize=(10, 4))
saor.violinplot(data=data, x="parental level of education", y="math score",bw=0.999999999999999)
# Out:
# <AxesSubplot:xlabel='parental level of education', ylabel='math score'>

# %%
mtltippo.figure(figsize=(10, 4))
saor.swarmplot(data=data, x="parental level of education", y="math score",hue ='gender')
# Out:
# /Users/andygu/opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 16.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/andygu/opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 7.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/andygu/opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 6.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='parental level of education', ylabel='math score'>

# %%
mtltippo.figure(figsize=(10, 4))
saor.boxenplot(data=data, x="parental level of education", y="math score",hue ='gender')
# Out:
# <AxesSubplot:xlabel='parental level of education', ylabel='math score'>

# %%
import pandas as pd
data = pd.read_csv('country_table.csv')
data
# Out:
#                          Countries  Birth rate  Mortality rate  \
# 0                           AFRICA      32.577           7.837
# 1                             ASIA      15.796           7.030
# 2                           EUROPE      10.118          11.163
# 3  LATIN AMERICA AND THE CARIBBEAN      15.886           6.444
# 4                 NORTHERN AMERICA      11.780           8.833
# 5                          OCEANIA      16.235           6.788
# 6                            WORLD      17.963           7.601
#
#    Life expectancy  Infant mortality rate  Growth rate
# 0           63.472                 44.215        24.40
# 1           73.787                 23.185         8.44
# 2           78.740                  3.750         0.38
# 3           75.649                 14.570         8.89
# 4           79.269                  5.563         6.11
# 5           78.880                 16.939        12.79
# 6           72.766                 27.492        10.36

# %%
data = data.set_index('Countries')
data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/0k/rfc7l8w10vg2gy6fqthn9r9r0000gn/T/ipykernel_37833/2501335407.py in <module>
# ----> 1 data = data.set_index('Countries')
#       2 data
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    5501
#    5502         if missing:
# -> 5503             raise KeyError(f"None of {missing} are in the columns")
#    5504
#    5505         if inplace:
#
# KeyError: "None of ['Countries'] are in the columns"

# %%
import seaborn as sns
sns.heatmap(data,annot = True)
# Out:
# <AxesSubplot:ylabel='Countries'>
