# %%
# load dm office sales files in yur python using pandas
import pandas as pna
import matplotlib.pyplot as plt
import seaborn as sns
data=pna.read_csv('dm_office_sales.csv')

# %%
plt.figure(figsize=(10, 4),dpi =200)
sns.countplot(x='division',data=data)
# Out:
# <AxesSubplot:xlabel='division', ylabel='count'>

# %%
plt.figure(figsize=(10, 4),dpi =200)
sns.countplot(x='level of education',data=data)
# Out:
# <AxesSubplot:xlabel='level of education', ylabel='count'>

# %%
plt.figure(figsize=(10, 5))
sns.countplot(x="level of education", data=data, hue = "training level")
# Out:
# <AxesSubplot:xlabel='level of education', ylabel='count'>

# %%
plt.figure(figsize=(10, 5))
sns.countplot(x="level of education", data=data)
# Out:
# <AxesSubplot:xlabel='level of education', ylabel='count'>

# %%
data=pna.read_csv('StudentsPerformance.csv')
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
index = (data['math score'] > 98) & (data['writing score'] > 98) & (data['reading score'] > 98)
data[index]
# Out:
#      gender race/ethnicity parental level of education     lunch  \
# 114  female        group E           bachelor's degree  standard
# 458  female        group E           bachelor's degree  standard
# 916    male        group E           bachelor's degree  standard
# 962  female        group E          associate's degree  standard
#
#     test preparation course  math score  reading score  writing score
# 114               completed          99            100            100
# 458                    none         100            100            100
# 916               completed         100            100            100
# 962                    none         100            100            100

# %%
plt.figure(figsize=(10, 4),dpi=200)
sns.boxplot(x="gender", y="reading score", data=data)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='reading score'>

# %%
plt.figure(figsize=(12, 4))
sns.boxplot(x ="parental level of education", y = "writing score", data = data,hue='gender')
# Out:
# <AxesSubplot:xlabel='parental level of education', ylabel='writing score'>

# %%
###  homework: please make boxplot of race/ethi.. then y = writing scroe hue = gender
plt.figure(figsize=(12, 4))
sns.boxplot(x ="race/ethnicity", y = "writing score", data = data,hue='gender')
# Out:
# <AxesSubplot:xlabel='race/ethnicity', ylabel='writing score'>

# %%
z = input("do we have class today?")

if z == "no":
   print("Why")

elif z == "yes":
    print("okay")

else:
    print("say it again pls")

    print(input(z))
# Out:
# say it again pls
# hfrvrekbdcjmndhkjkcmkelkjcfnfur vcbujefnrjnriojknfwapiewlrjghvjjkfhtvijoekrmnfikjrhufgjk

# %%
data=pna.read_csv('StudentsPerformance.csv')

# %%
index = data['math score'] < 50
data[index]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 3      male        group A          associate's degree  free/reduced
# 7      male        group B                some college  free/reduced
# 9    female        group B                 high school  free/reduced
# 11     male        group D          associate's degree      standard
# 17   female        group B            some high school  free/reduced
# ..      ...            ...                         ...           ...
# 961  female        group D            some high school  free/reduced
# 973  female        group D                some college  free/reduced
# 980  female        group B                 high school  free/reduced
# 986  female        group C          associate's degree      standard
# 988  female        group A            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
## box plot to show average of maths studnets
sns.boxplot(x="math score", data = data )
# Out:
# <AxesSubplot:xlabel='math score'>

# %%
data.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
index = data['math score'] == 0
data[index]
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 59  female        group C            some high school  free/reduced
#
#    test preparation course  math score  reading score  writing score
# 59                    none           0             17             10

# %%
sns.scatterplot(data=data, x="math score", y="writing score", hue="gender")
# Out:
# <AxesSubplot:xlabel='math score', ylabel='writing score'>

# %%
data['gender'].value_counts()#.plot(kind='bar')
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
data['parental level of education'].value_counts()#.plot(kind='bar')
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64

# %%
data['parental level of education'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
sns.scatterplot(data=data, x="gender", y="test preparation course", hue="math score")
# Out:
# <AxesSubplot:xlabel='gender', ylabel='test preparation course'>

# %%
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
### to make histogram of race/ethicity then make a histograme for math score and tell me the total sum of all scores in as new column and make a caculator

# %%
while(True):
    z = input("what do you want me to caculate? ")
    if z == "exit":
        break
    if "^" in z:
        a = z.replace("^", "**")
        print(eval(a))
    elif "x" in z:
        q = z.replace("x", "*")
        print(eval(q))
    elif "÷" in z:
        o = z.replace("÷", "/")
        print(eval(o))
    else:
        print(eval(z))
# Out:
# 0.6666666666666666
# 16
# 36
# 469
# 126
# 47639487

# %%
sns.histplot(data=data, x="race/ethnicity", hue="gender")
# Out:
# <AxesSubplot:xlabel='race/ethnicity', ylabel='Count'>

# %%
sns.histplot(data=data, x='math score',hue='gender')
# Out:
# <AxesSubplot:xlabel='math score', ylabel='Count'>

# %%
data ['new col sum']  =  data["math score"] + data["writing score"] + data['reading score']

# %%
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  sum  \
# ...
