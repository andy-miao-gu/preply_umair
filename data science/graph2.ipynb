# %%
# import pandas and load csv file
import pandas as pd


# read csv file
data = pd.read_csv('dm_office_sales.csv')

# %%
data.head()
# Out:
#           division  level of education  training level  work experience  \
# 0         printers        some college               2                6
# 1         printers  associate's degree               2               10
# 2      peripherals         high school               0                9
# 3  office supplies  associate's degree               2                5
# 4  office supplies         high school               1                5
#
#    salary   sales
# 0   91684  372302
# 1  119679  495660
# 2   82045  320453
# 3   92949  377148
# 4   71280  312802

# %%
data.tail(10)
# Out:
#               division  level of education  training level  work experience  \
# 990           printers        some college               0                3
# 991  computer software  associate's degree               2                4
# 992        peripherals        some college               2                0
# 993           printers        some college               0                9
# 994           printers         high school               1                5
# 995  computer hardware  associate's degree               1                1
# 996  computer software  associate's degree               1                0
# 997        peripherals  associate's degree               2                8
# 998        peripherals  associate's degree               2                3
# 999  computer hardware        some college               0                9
#
#      salary   sales
# 990   68353  175274
# 991   99417  313247
# 992   51072  150716
# 993   89281  348428
# 994   75139  310468
# ...

# %%
### i am interest in those people who are from computer software and there level of security is associat exper8 or more
index = (data['division']=='computer software') & (data['level of education']=="associate's degree") & (data['work experience']>8)
data[index]
# Out:
#               division  level of education  training level  work experience  \
# 66   computer software  associate's degree               1                9
# 103  computer software  associate's degree               3               15
# 128  computer software  associate's degree               1               10
# 174  computer software  associate's degree               2               12
# 254  computer software  associate's degree               1               11
# 695  computer software  associate's degree               1               10
# 872  computer software  associate's degree               0                9
# 929  computer software  associate's degree               2               13
#
#      salary   sales
# 66   121184  380183
# 103  159148  761477
# 128  115164  421642
# 174  134965  579652
# 254  128594  498153
# 695  129220  418925
# 872  110110  327684
# 929  140740  606125

# %%
### i need data with those people who are from associate degrees and there experience is 10....
index =(data['level of education']=="associate's degree") & (data['work experience']=10)
data_asso_10 = data[index]

# %%
import seaborn as sns
sns.scatterplot(x="salary", y="sales", data=data, hue = 'level of education',)
# Out:
# <AxesSubplot:xlabel='salary', ylabel='sales'>

# %%
import seaborn as sns
sns.scatterplot(x="salary", y="sales", data=data, size = 'work experience',hue= 'division')
# Out:
# <AxesSubplot:xlabel='salary', ylabel='sales'>

# %%
data100 = data.iloc[:100,:]

# %%
import seaborn as sns
sns.scatterplot(x="salary", y="sales", data=data100, style = 'division',s=100)
# Out:
# <AxesSubplot:xlabel='salary', ylabel='sales'>

# %%
import seaborn as sns
sns.scatterplot(x="salary", y="sales", data=data100, style = 'division',s=100, hue = 'division')
# Out:
# <AxesSubplot:xlabel='salary', ylabel='sales'>

# %%
## nature of salary
sns.histplot(x="salary", data=data,bins = 100)
# Out:
# <AxesSubplot:xlabel='salary', ylabel='Count'>

# %%
## nature of salary
sns.displot(x="salary", data=data,bins = 100,kde = True)

# %%
## nature of salary
sns.kdeplot(x="salary", data=data)
# Out:
# <AxesSubplot:xlabel='salary', ylabel='Density'>

# %%
## telll em the nature of sales
## nature of salary
sns.kdeplot(x="sales", data=data,)
# Out:
# <AxesSubplot:xlabel='sales', ylabel='Density'>

# %%
sns.kdeplot(x="salary", data=data,shade = True, color='red')
# Out:
# <AxesSubplot:xlabel='salary', ylabel='Density'>

# %%
## make a shaded version of sales with kde
sns.kdeplot(x="sales", data=data,shade = True, color='red')
sns.kdeplot(x="sales", data=data,shade = True, color='yellow')
sns.kdeplot(x="sales", data=data,shade = True, color='red')
sns.kdeplot(x="sales", data=data,shade = True, color='white')
sns.kdeplot(x="sales", data=data,shade = True, color='green')
sns.kdeplot(x="sales", data=data,shade = True, color='orange')
sns.kdeplot(x="sales", data=data,shade = True, color='orange')
sns.kdeplot(x="sales", data=data,shade = True, color='orange')
sns.kdeplot(x="sales", data=data,shade = True, color='purple')
sns.kdeplot(x="sales", data=data,shade = True, color='purple')
sns.kdeplot(x="sales", data=data,shade = True, color='purple')
sns.kdeplot(x="sales", data=data,shade = True, color='orange')
sns.kdeplot(x="sales", data=data,shade = True, color='pink')
sns.kdeplot(x="sales", data=data,shade = True, color='purple')
sns.kdeplot(x="sales", data=data,shade = True, color='pink')
sns.kdeplot(x="sales", data=data,shade = True, color='white')
sns.kdeplot(x="sales", data=data,shade = True, color='pink')
sns.kdeplot(x="sales", data=data,shade = True, color='purple')
sns.kdeplot(x="sales", data=data,shade = True, color='blue')
sns.kdeplot(x="sales", data=data,shade = True, color='orange')
sns.kdeplot(x="sales", data=data,shade = True, color='blue')
sns.kdeplot(x="sales", data=data,shade = True, color='gray')
sns.kdeplot(x="sales", data=data,shade = True, color='orange')
sns.kdeplot(x="sales", data=data,shade = True, color='violet')
sns.kdeplot(x="sales", data=data,shade = True, color='lavender')
sns.kdeplot(x="sales", data=data,shade = True, color='violet')
sns.kdeplot(x="sales", data=data,shade = True, color='lavender')
sns.kdeplot(x="sales", data=data,shade = True, color='purple')
sns.kdeplot(x="sales", data=data,shade = True, color='blue')
sns.kdeplot(x="sales", data=data,shade = True, color='orange')
sns.kdeplot(x="sales", data=data,shade = True, color='gray')
sns.kdeplot(x="sales", data=data,shade = True, color='white')
sns.kdeplot(x="sales", data=data,shade = True, color='purple')
sns.kdeplot(x="sales", data=data,shade = True, color='violet')
sns.kdeplot(x="sales", data=data,shade = True, color='lavender')
sns.kdeplot(x="sales", data=data,shade = True, color='red')
sns.kdeplot(x="sales", data=data,shade = True, color='purple')
sns.kdeplot(x="sales", data=data,shade = True, color='violet')
sns.kdeplot(x="sales", data=data,shade = True, color='lavender')
sns.kdeplot(x="sales", data=data,shade = True, color='violet')
sns.kdeplot(x="sales", data=data,shade = True, color='lavender')
sns.kdeplot(x="sales", data=data,shade = True, color='red')
sns.kdeplot(x="sales", data=data,shade = True, color='violet')
sns.kdeplot(x="sales", data=data,shade = True, color='lavender')
sns.kdeplot(x="sales", data=data,shade = True, color='purple')
sns.kdeplot(x="sales", data=data,shade = True, color='violet')
sns.kdeplot(x="sales", data=data,shade = True, color='orange')
sns.kdeplot(x="sales", data=data,shade = True, color='violet')
sns.kdeplot(x="sales", data=data,shade = True, color='red')
sns.kdeplot(x="sales", data=data,shade = True, color='violet')
sns.kdeplot(x="sales", data=data,shade = True, color='lavender')
sns.kdeplot(x="sales", data=data,shade = True, color='violet')
sns.kdeplot(x="sales", data=data,shade = True, color='red')
sns.kdeplot(x="sales", data=data,shade = True, color='pink')
sns.kdeplot(x="sales", data=data,shade = True, color='lavender')
sns.kdeplot(x="sales", data=data,shade = True, color='violet')
sns.kdeplot(x="sales", data=data,shade = True, color='purple')
# Out:
# <AxesSubplot:xlabel='sales', ylabel='Density'>

# %%
import matplotlib.pyplot as plt

# %%
## count plot
plt.figure(figsize=(10, 4))
sns.countplot(data=data,x = 'division')
# Out:
# <AxesSubplot:xlabel='division', ylabel='count'>

# %%
ndata = data[data['divsion']=='printers']
# Out:
#               division  level of education  training level  work experience  \
# 0             printers        some college               2                6
# 1             printers  associate's degree               2               10
# 2          peripherals         high school               0                9
# 3      office supplies  associate's degree               2                5
# 4      office supplies         high school               1                5
# ..                 ...                 ...             ...              ...
# 995  computer hardware  associate's degree               1                1
# 996  computer software  associate's degree               1                0
# 997        peripherals  associate's degree               2                8
# 998        peripherals  associate's degree               2                3
# 999  computer hardware        some college               0                9
#
#      salary   sales
# 0     91684  372302
# ...

# %%
# 1. if i select on printers ,,,,,,make count plot of level of education
# 2. make shadded plot for sales
# 3. then tell me the salary of each person with histogram and kde
"""
## count plot
a=(data['division']==['printers'])
ntplot(data=data,x = a)

## make a shaded version of sales with kde
sns.kdeplot(x="sales", data=data,shade = True, color='red')
sns.kdeplot(x="sales", data=data,shade = True, color='yellow')
sns.kdeplot(x="sales", data=data,shade = True, color='red')
sns.kdeplot(x="sales", data=data,shade = True, color='white')
sns.kdeplot(x="sales", data=data,shade = True, color='green')
sns.kdeplot(x="sales", data=data,shade = True, color='orange')
sns.kdeplot(x="sales", data=data,shade = True, color='orange')
sns.kdeplot(x="sales", data=data,shade = True, color='orange')
sns.kdeplot(x="sales", data=data,shade = True, color='purple')
sns.kdeplot(x="sales", data=data,shade = True, color='purple')
sns.kdeplot(x="sales", data=data,shade = True, color='purple')
sns.kdeplot(x="sales", data=data,shade = True, color='orange')
sns.kdeplot(x="sales", data=data,shade = True, color='pink')
sns.kdeplot(x="sales", data=data,shade = True, color='purple')
sns.kdeplot(x="sales", data=data,shade = True, color='pink')"""



####hint for third 
dp = data[data['division'] == 'printers']
sns.countplot(x="level of education", data=dp)
plt.show()
sns.kdeplot(x="sales", data=dp,shade = True, color='red')
plt.show()
sns.histplot(x="salary", data=dp)
# Out:
# <AxesSubplot:xlabel='salary', ylabel='Count'>

# %%
sns.kdeplot(x="sales", data=data,shade = True, color='purple')
# Out:
# <AxesSubplot:xlabel='sales', ylabel='Density'>

# %%
sns.kdeplot(x="sales", data=data,shade = True, color='lavender')
# Out:
# <AxesSubplot:xlabel='sales', ylabel='Density'>

# %%
sns.kdeplot(x="sales", data=data,shade = True, color='violet')
# Out:
# <AxesSubplot:xlabel='sales', ylabel='Density'>

# %%
# Out:
# fggdrfgrctfgbrty
