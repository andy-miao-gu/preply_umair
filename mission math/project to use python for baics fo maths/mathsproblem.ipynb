# %% [markdown]
# #### Fibonacci Sequence
# Write a program to generate the Fibonacci sequence up to a given term n.

# %%
import math as mt
import matplotlib.pyplot as plt
F0 = 0
F1 = 1
F2 = F1 + F0
F3 = F2 + F1 
F4 = F3 + F2
F5 = F4 + F3
print(F5)
#F10??
F6 = F5 + F4
F7 = F6 + F5
F8 = F7 + F6
F9 = F8 + F7
F10 = F9 + F8
print(F10)
# Out:
# 5
# 55

# %%
def function(parameter):
    F0 = 0
    F1 = 1
    Fn = 0
    for i in range(2, parameter + 1):
        Fn = F0 + F1
        F0 = F1 
        F1 = Fn
    return Fn


# make a list of 1 to 20
inp = [each for each in range(2,1000) ]
# fnd the fibnoshi of each number 
out = [function(each) for each in inp]

# plot it 
plt.plot(inp, out)

# %% [markdown]
# #### Prime Number Generator
# you have to tell is the number prime or not

# %%
# create a prime number function that has it from x to y
def prime_number(are_prime):
    not_prime="prime"
    for each in range(2,are_prime):
        
        if are_prime%each==0 :
            print("divisbe on",each)
            not_prime="not prime"
            break
            
    if are_prime == 1:
        not_prime = "releatively prime"
          
    return not_prime
prime_number(10000000001)
# Out:
# divisbe on 101
# 'not prime'

# %% [markdown]
# #### Factorial Calculator
# Design a program to calculate the factorial of a given integer n.

# %%
mt.factorial(5)
# Out:
# 120

# %%
f = 5

final = 1
for each in range(1,f+1):
    print(each,"x",final,'=',end=" ")
    final = final * each
    print(final)
print(final)
# Out:
# 1 x 1 = 1
# 2 x 1 = 2
# 3 x 2 = 6
# 4 x 6 = 24
# 5 x 24 = 120
# 120

# %% [markdown]
# #### Greatest Common Divisor (GCD)
# Write a program to find the GCD of two integers a and b using the Euclidean algorithm.

# %%
mt.gcd(30,66)
# Out:
# 6

# %% [markdown]
# #### Root Finding
# Implement a numerical method like the Newton-Raphson method to find the root of a given function.

# %%
from scipy.optimize import fsolve
f = lambda x: 10*x**6 + 4*x+37

fsolve(f, [3, 1])
# Out:
# /Users/andymiaogu/anaconda3/lib/python3.10/site-packages/scipy/optimize/_minpack_py.py:178: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
#   warnings.warn(msg, RuntimeWarning)
# array([ 1.22576036, -0.59467189])

# %%
f(0)
# Out:
# 37

# %%
import numpy as np

# %%
x0 = np.arange(-10,10,0.1)
y  = [f(each) for each in x0]
plt.plot(x0,y)

# %% [markdown]
# #### Matrix Operations
# Develop a program for matrix multiplication, addition, and subtraction.

# %%
def matrix(mys,mys2):
    mys = np.array(mys)
    mys2 = np.array(mys2)
    x=mys+mys2
    y=mys-mys2
    z=mys*mys2
    return {"sum":x,"diff":y,"prd":z}
matrix([[1,2],[3,4]],[[5,6],[8,9]])
# Out:
# {'sum': array([[ 6,  8],
#         [11, 13]]),
#  'diff': array([[-4, -4],
#         [-5, -5]]),
#  'prd': array([[ 5, 12],
#         [24, 36]])}

# %% [markdown]
# #### Sieve of Eratosthenes
# Create a program to find all prime numbers less than or equal to a given number n.

# %%
###make function to make prime number from x to y

###write for loop

###make hypothesis if perimeter is only divis by itself and 1 write perimeter="prime"

###else then perimeter = "not prime"

###return {"perimeter is": perimeter}

# %% [markdown]
# #### Sudoku Solver
# Write a program to solve Sudoku puzzles using backtracking or constraint propagation algorithms.

# %%
# try yourel

# %%
# use google

# %%
# use chatgpt

# %% [markdown]
# #### Series Summation
# Develop a program to calculate the sum of an infinite series, such as the geometric series or the Taylor series for a mathematical function.

# %%
error
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[129], line 1
# ----> 1 error
#
# NameError: name 'error' is not defined

# %% [markdown]
# #### Linear Regression
# Implement a linear regression algorithm to find the best-fit line for a set of data points.

# %%
list(  (1,2,3,4)      )
# Out:
# [1, 2, 3, 4]

# %%
x = np.array((1,2,3,4,5,6))
y =np.array((6,10,12,20,23,30))




m,c =np.polyfit( x,y, 1)
z = m*x+c
plt.plot(x,y,".-")
plt.plot(x,z,".-")
plt.legend(['actaul data','poly fitted regression'])

# %%
dry
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[127], line 1
# ----> 1 dry
#
# NameError: name 'dry' is not defined

# %%
# make a code that will not work!
for we in range(50)
# Out:
#   Cell In[128], line 2
#     for we in range(50)
#                        ^
# SyntaxError: expected ':'
