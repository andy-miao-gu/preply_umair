# %%
import numpy as np

# %%
# eq : y = 6.5*x
import matplotlib.pyplot as plt

# %%
x= np.arange(-10,10.5,0.5)
y= 100*x**2 + 10
plt.plot(x,y)

# %%
x =  np.array([ [ 55,23,45],[32,4,2] ])
# Out:
# array([[55, 23, 45],
#        [32,  4,  2]])

# %%
import pandas as pd
datai = pd.DataFrame(x, columns=["Day1", "Day2", "Day3"],index = ["hours","miles"])
datai
# Out:
#        Day1  Day2  Day3
# hours    55    23    45
# miles    32     4     2

# %%
import seaborn as promax
promax.barplot(x = "Day1", data=datai)
# Out:
# <Axes: xlabel='Day1'>

# %%
y =  np.array( [[1,2,3],[530,1060,1590] ])
dataii=pd.DataFrame(y,index=["hours","miles"],columns=['','',''])

# %%
dataii
# Out:
#
# hours    1     2     3
# miles  530  1060  1590
