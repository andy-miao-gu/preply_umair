# %%
import pandas
datfram=pandas.read_csv("pepenguins_size.csv")

# %%
datfram.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   culmen_length_mm   342 non-null    float64
#  3   culmen_depth_mm    342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                334 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
# drop empt lines
df = datfram.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 334 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            334 non-null    object
#  1   island             334 non-null    object
#  2   culmen_length_mm   334 non-null    float64
#  3   culmen_depth_mm    334 non-null    float64
#  4   flipper_length_mm  334 non-null    float64
#  5   body_mass_g        334 non-null    float64
#  6   sex                334 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 20.9+ KB

# %%
df['sex'].unique()
# Out:
# array(['MALE', 'FEMALE', '.'], dtype=object)

# %%
df['island'].unique()
# Out:
# array(['Torgersen', 'Biscoe', 'Dream'], dtype=object)

# %%
### show me data  where i have sex as dash .
df_no_dash_sorry_dash = df[df['sex'] != "."]

# %%
df_no_dash_sorry_dash.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 333 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            333 non-null    object
#  1   island             333 non-null    object
#  2   culmen_length_mm   333 non-null    float64
#  3   culmen_depth_mm    333 non-null    float64
#  4   flipper_length_mm  333 non-null    float64
#  5   body_mass_g        333 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 20.8+ KB

# %%
import seaborn as sns
sns.catplot(x='species', y='culmen_length_mm',data = df_no_dash_sorry_dash, col='sex',kind = 'box')

# %%
import seaborn as sns
sns.catplot(x='species', y='culmen_depth_mm',data = df_no_dash_sorry_dash, col='sex',kind = 'box')

# %%
import seaborn as sns
sns.catplot(x='species', y='body_mass_g',data = df_no_dash_sorry_dash, col='sex',kind = 'box')

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from PIL import Image
import numpy as np
img = Image.open("a-cat.webp")
img = np.array(img)

# %% [markdown]
# )

# %%
img.shape
# Out:
# (702, 1245, 3)

# %%
crop = img[100:700,400:1100, :]
plt.imshow(crop)
plt.axis('off')
plt.savefig("andy_likesit.png")

# %%
crop = img[100:700,400:1100, 1]
plt.imshow(crop)
plt.axis('off')
plt.savefig("andy_likesit.png")

# %%
## homework = "go to chat gpt and type make a dicison tree sklearn codee "

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics


# Create a decision tree classifier object
dt_classifier = DecisionTreeClassifier()

X = df_no_dash_sorry_dash.drop('sex',axis=1)
X = X[['culmen_length_mm','culmen_depth_mm']]
y = df_no_dash_sorry_dash[['species','sex']]
# Train the decision tree classifier on the training data
dt_classifier.fit(X, y)
# Out:
# DecisionTreeClassifier()

# %%
# Predict the classes of test data
y_pred = dt_classifier.predict([[46,17]]) # lenth and depth
y_pred
# Out:
# /Users/andygu/opt/anaconda3/envs/dsml/lib/python3.10/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([['Chinstrap', 'FEMALE']], dtype=object)

# %%
sns.catplot(x='species', y='culmen_length_mm',data = df_no_dash_sorry_dash, col='sex',kind = 'box')

# %%
sns.catplot(x='species', y='culmen_depth_mm',data = df_no_dash_sorry_dash, col='sex',kind = 'box')

# %%
from fractions import Fraction
Fraction(88888,52)
# Out:
# Fraction(22222, 13)

# %%
import numpy as np
np.power(27,1/3)
# Out:
# 3.0

# %%
### find the spec
# Out:
# 10.000000000000002

# %%
## based on weight of penguin train a decision tree model to prediction the male or female and species! HOMEWORKDKKKKKKSADKSD vmb mkfglkfkgthpognopfdlnpomkhktmn

from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics


# Create a decision tree classifier object
dt_classifier = DecisionTreeClassifier()

X = df_no_dash_sorry_dash.drop('sex',axis=1)
X = X[['body_mass_g']]
y = df_no_dash_sorry_dash[['sex','species']]
# Train the decision tree classifier on the training data
dt_classifier.fit(X, y)
# Out:
# DecisionTreeClassifier()

# %%
# Predict the classes of test data
y_pred = dt_classifier.predict([[46]]) # lenth and depth
y_pred
# Out:
# /Users/andygu/opt/anaconda3/envs/dsml/lib/python3.10/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([['FEMALE', 'Chinstrap']], dtype=object)

# %%
import seaborn

# %%
seaborn.catplot(kind="box",x= "species", y="body_mass_g",col="sex",data=df_no_dash_sorry_dash)
